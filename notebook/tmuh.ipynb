# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
from urllib.parse import urlparse

# %%
import sys
from pathlib import Path
sys.path.append(Path().cwd().parent.as_posix())

from hospwork import get_work_page
from hospwork import findjobtype

# %%
url_base='https://www.tmuh.org.tw'
url_work_table='/recruit/'
url=url_base+url_work_table
g=requests.get(url)
soup=BeautifulSoup(g.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>
# 	臺北醫學大學附設醫院
# </title><meta content="app-id=1190014257" name="apple-itunes-app"/><meta content="app-id=com.tmu.ihealth" name="google-play-app"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width,minimum-scale=1,maximum-scale=1" name="viewport"/><meta name="description"/><meta content="true" name="HandheldFriendly"/><meta content="320" name="MobileOptimized"/>
# <link href="/favicon.ico" rel="icon"/>
# <!-- Latest compiled and minified CSS -->
# <link href="/bootstrap/css/bootstrap.css" rel="stylesheet"/><link href="/bootstrap/css/bootstrap-theme.css" rel="stylesheet"/>
# <!-- Latest compiled and minified JavaScript -->
# <link href="/js/css/jquery-ui.css" rel="stylesheet"/><link href="/font-awesome/css/font-awesome.min.css" rel="stylesheet"/><link href="/Content/carousel.css" rel="stylesheet"/><link href="/Content/Site.css" rel="stylesheet"/><link href="/Content/web.css" rel="stylesheet"/><link href="/js/css/bootstrap-select.css" rel="stylesheet"/><link href="/js/revolution/medical.css" rel="stylesheet"/><link href="/js/css/sweetalert2.min.css" rel="stylesheet"/>
# <script src="/js/element.js?cb=googleTranslateElementInit" type="text/javascript"></script>
# <script async="async" src="/js/sharethis.js#property=60178a255705640011df1990&amp;product=inline-share-buttons" type="text/javascript"></script>
# <script src="/js/jquery/core/jquery-1.11.2.min.js"></script>
# <script src="/js/jquery/core/jquery-ui-1.11.4.js"></script>
# <script src="/bootstrap/js/bootstrap.min.js"></script>
# <script src="/js/handlebars/handlebars-v3.0.0.js"></script>
# <script src="/js/jquery/plugins/bootstrap-select.js"></script>
# <script src="/js/sweetalert2.min.js"></script>
# <link href="../js/appbanner/smart-app-banner.css" rel="stylesheet"/><link href="/icon.png" rel="apple-touch-icon"/><link href="/icon.png" rel="android-touch-icon"/>
# <script src="../js/appbanner/smart-app-banner.js"></script>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
# <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#       <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
# <script src="../js/validator.js"></script>
# <script>
#         $(document).ready(function () {
#             var code = $("#MainPlaceHolder_hidCode").val();
#             $("#job_" + code).addClass("active");
#         });
#     </script>
# <script>
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date(); a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#         //ga('create', 'UA-100556829-1', 'auto');
#         ga('create', 'UA-100556829-1', {'cookieFlags': 'SameSite=None; Secure'});
#         ga('send', 'pageview');
#
#
#         banner = undefined;
#         jQuery(document).ready(function ($) {
#             if (getMobileOperatingSystem() === "Android") {
#                 run('android');
#             } else if (getMobileOperatingSystem() === "iOS") {
#                 run('ios')
#             }
#         });
#
# 	function run(force) {
# 		var n = document.querySelector('.smartbanner');
# 		if (n) {
# 			n.parentNode.removeChild(n);
# 		}
# 		new SmartBanner({
# 				daysHidden: 1, // days to hide banner after close button is clicked (defaults to 15)
# 				daysReminder: 1, // days to hide banner after "VIEW" button is clicked (defaults to 90)
# 				appStoreLanguage: 'us', // language code for the App Store (defaults to user's browser language)
#                 title: '北醫掛號',
#                 author: '台北醫學大學附設醫院',
# 				button: '下載',
# 				force: force
# 		});
#     };
#     function getMobileOperatingSystem() {
#         var userAgent = navigator.userAgent || navigator.vendor || window.opera;
#
#         if (/android/i.test(userAgent)) {
#             return "Android";
#         }
#
#         // iOS detection from: http://stackoverflow.com/a/9039885/177710
#         if (/iPad|iPhone|iPod/.test(userAgent) && !window.MSStream) {
#             return "iOS";
#         }
#
#         return "unknown";
#         }
#
#     function googleTranslateElementInit() {//20210330新增簡體繁體轉換
#
#         new google.translate.TranslateElement({ pageLanguage: 'zh-TW', includedLanguages: 'zh-CN,zh-TW', layout: google.translate.TranslateElement.InlineLayout.SIMPLE }, 'google_translate_element');
#
#         }
#
#
#     </script>
# <style>
#         .smartbanner-show {
#             margin-top: unset;
#             margin-bottom: 40px;
#         }
#         .smartbanner-container {
#             line-height: 82px;
#         }
#         .smartbanner {
#             position: fixed;
#             top:unset;
#             bottom: 0;
#         }
#         .smartbanner-info div, .smartbanner-info span {
#             font-size: 12px;
#             line-height: 14.4px;
#         }
#     </style>
# </head>
# <body role="document">
# <form action="./" id="form1" method="post">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="96325383"/>
# <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="..."/>
# <script>
#     //沒有再使用這段程式-------------
#     var symptom = [];
#     var doctor = [];
#     $(document).ready(function () {
#         $("#cate").change(function () {
#             var sel = $(this).val();
#             $("#uc_header1_hidCate").val(sel);
#
#             if (sel == "A") {
#                 $.getJSON('/webserv/ws_service.asmx/SymptomAll', function(json) {
#                     symptom = eval(json);
#                     //console.log(symptom);
#                     $("#uc_header1_txtKwd").autocomplete({
#                         source: symptom
#                     });
#                 });
#             } else if (sel == "B") {
#                 $.getJSON('/webserv/ws_service.asmx/DoctorAll', function (json) {
#                     doctor = eval(json);
#                     $("#uc_header1_txtKwd").autocomplete({
#                         source: doctor
#                     });
#                 });
#             }
#         });
#     });
#     //---------------------------------
#
#     $('#myTab a').click(function(e) {
#         e.preventDefault();
#         $(this).tab('show');
#     });
#
#
#     function setCookie(cname,cvalue,exdays)//紀錄字體大小
#     {
#         var d = new Date();
#         d.setTime(d.getTime()+(exdays*24*60*60*1000));
#         var expires = "expires="+d.toGMTString();
#         document.cookie = cname + "=" + cvalue + "; " + expires + "; path=/";
#         document.cookie = cname + "=" + cvalue + "; " + expires + "; path=/cms";
#         document.cookie = cname + "=" + cvalue + "; " + expires + "; path=/team";
#         document.cookie = cname + "=" + cvalue + "; " + expires + "; path=/service";
#
#     }
#
#     function getCookie(cname)//擷取之前字體大小
#     {
#         var name = cname + "=";
#         var ca = document.cookie.split(';');
#         for(var i=0; i<ca.length; i++)
#         {
#             var c = ca[i].trim();
#             if (c.indexOf(name)==0) return c.substring(name.length,c.length);
#         }
#         return "";
#     }
#
#     $(document).ready(function ($) {//字體大小功能20210320
#         // Set initial zoom level
#         var zoom_level = 100;
#
#         if (getCookie('webzl') != "") {
#             zoom_page(getCookie('webzl') - zoom_level, $(this));
#         }
#
#
#         // Click events
#         $('#zoom_in').click(function () { zoom_page(5, $(this)) });
#         $('#zoom_out').click(function () { zoom_page(-10, $(this)) });
#         $('#zoom_reset').click(function () { zoom_page(0, $(this)) });
#
#         // Zoom function
#         function zoom_page(step, trigger) {
#             // Zoom just to steps in or out
#             if (zoom_level >= 110 && step > 0 || zoom_level <= 80 && step < 0) return;
#
#             // Set / reset zoom
#             if (step == 0) zoom_level = 100;
#             else zoom_level = zoom_level + step;
#
#             // Set page zoom via CSS
#             $('.navbar').css({
#                 transform: 'scale(' + (zoom_level / 100) + ')', // set zoom
#                 transformOrigin: '50% 0' // set transform scale base
#             });
#             $('.footer').css({
#                 transform: 'scale(' + (zoom_level / 100) + ')', // set zoom
#                 transformOrigin: '50% 0' // set transform scale base
#             });
#             $('.text-center').css({
#                 transform: 'scale(' + (zoom_level / 100) + ')', // set zoom
#                 transformOrigin: '50% 0' // set transform scale base
#             });
#             $('.breadcrumb').css({
#                 transform: 'scale(' + (zoom_level / 100) + ')', // set zoom
#                 transformOrigin: '50% 0' // set transform scale base
#             });
#             $('.fullwidthbanner').css({
#                 transform: 'scale(' + (zoom_level / 100) + ')', // set zoom
#                 transformOrigin: '50% 0' // set transform scale base
#             });
#             $('.homebody').css({
#                 transform: 'scale(' + (zoom_level / 100) + ')', // set zoom
#                 transformOrigin: '50% 0' // set transform scale base
#             });
#             $('.page-body').css({
#                 transform: 'scale(' + (zoom_level / 100) + ')', // set zoom
#                 transformOrigin: '50% 0' // set transform scale base
#             });
#
#
#             // Adjust page to zoom width
#             if (zoom_level > 100) $('.navbar').css({ width: (zoom_level * 0) + '%' });
#             else $('.navbar').css({ width: '100%' });
#
#
#             // Activate / deaktivate trigger (use CSS to make them look different)
#             if (zoom_level >= 120 || zoom_level <= 80) trigger.addClass('disabled');
#             else trigger.parents('ul').find('.disabled').removeClass('disabled');
#             if (zoom_level != 100) $('#zoom_reset').removeClass('disabled');
#             else $('#zoom_reset').addClass('disabled');
#
#
#             setCookie('webzl', zoom_level, 2);
#         }
#     });
#
#
#     function AntiSqlValid() {//防止SQL攻擊
#         var t = $("#uc_header1_txtKwd");
#         if (!$(t).checkEmpty('請輸入關鍵字！')) return false;
#         re = /select|update|delete|exec|count|'|"|=|;|>|<|%/i;
#         if (re.test(t.val())) {
#             alert("查詢無結果"); //注意中文亂碼
#             return false;
#         }
#     }
# </script>
# <style>
#     /*連結到英文官網的連結在手機板才會顯示，桌面板不會顯示*/
#     .menu_item {
#         display:none;
#     }
#     .search_option{
#         display:inline-block;
#     }
#     .pull-right{
#         height:35px;
#     }
#
#     @media screen and (max-width: 767px) {
#         .menu_item {
#             display:block;
#         }
#         .search{
#             position:fixed;
#             right:15px;
#             top:65px;
#         }
#         .search .eng_link{
#             display:none;
#         }
#         .navbar-header{
#            /*margin-bottom:40px;*/
#         }
#         .form-control{
#             width:100%;
#             left:0;
#         }
#         .navbar-collapse{
#             max-height:none !important;
#         }
#     }
#
#     .header .navbar-brand img.itpass_link {
#         height: 78px;
#     }
#     .sfont {
#         font-size: 18px;
#         font-family: 微軟正黑體;
#         color: #009688;
#         font-weight: bold;
#     }
#     .sfont_set {
#         padding: 14px 0px 0px 6px;
#     }
#
#     @media screen and (max-width: 1024px) {
#       .header .navbar-brand img.itpass_link {
#         height: 78px;
#       }
#     }
#
#     @media screen and (max-width: 768px) {
#         .header .navbar-brand img.itpass_link {
#             height: 40px;
#         }
#         a.navbar-brand {
#             padding-right: 0;
#             padding-left: 0;
#         }
#         .sfont_set {
#             display:none;
#         }
#     }
#
#     .goog-te-banner-frame, .goog-te-gadget-icon{/*隱藏翻譯工作列及google圖示*/
#         display:none;
#     }
#
# </style>
# <div class="navbar navbar-default navbar-fixed-top header">
# <div class="container">
# <div class="navbar-header">
# <div>
# <div>
# <a class="navbar-brand" href="/">
# <img alt="回首頁" class="tmuh_logo" src="/images/logo.jpg"/>
# </a>
# <a class="navbar-brand" href="https://www.tmuh.org.tw/single/5038">
# <img alt="itpass" class="itpass_link" src="/images/itpass.gif"/>
# </a>
# <div class="navbar-brand text-center sfont_set">
# <span class="sfont">點擊下載</span><br/>
# <span class="sfont">iTPass</span>
# </div>
# </div>
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar" data-toggle="collapse" style="position:fixed; right:5px;" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <div class="text-right search" id="Search">
# <a class="eng_link" href="http://english.tmuh.org.tw">English</a>
# <div class="form-inline">
# <div style="display:inline-block; margin-right:3px;">
# <input class="form-control" id="uc_header1_txtKwd" maxlength="20" name="ctl00$uc_header1$txtKwd" placeholder="請輸入關鍵字" type="text"/>
# <input id="uc_header1_hidCate" name="ctl00$uc_header1$hidCate" type="hidden" value="A"/>
# </div>
# <a class="btn btn-search" href="javascript:__doPostBack('ctl00$uc_header1$btnSearch1','')" id="uc_header1_btnSearch1" onclick="return AntiSqlValid();">
# <i class="fa fa-search"></i>
# </a>
#                         字體設定 <div class="btn btn-success" id="google_translate_element"></div>
# <a class="active btn btn-info" id="zoom_in">大</a>
# <a class="active btn btn-info" id="zoom_out">小</a>
# <a class="active btn btn-info" id="zoom_reset">還原</a>
# </div>
# </div>
# </div>
# <div class="collapse navbar-collapse" id="navbar">
# <ul class="nav navbar-nav navbar-right">
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="../uc/#" id="uc_header1_rpMenu_lnkName_0" role="button">認識北醫 <span class="caret"></span></a>
# <ul class="dropdown-menu" id="uc_header1_rpMenu_subMenu_0" role="menu">
# <li>
# <a href="/cms/goal" id="uc_header1_rpMenu_rpSub_0_lnkName_0">願景目標</a>
# </li>
# <li>
# <a href="/cms/about" id="uc_header1_rpMenu_rpSub_0_lnkName_1">本院介紹</a>
# </li>
# <li>
# <a href="/cms/dean" id="uc_header1_rpMenu_rpSub_0_lnkName_2">院長的話</a>
# </li>
# <li>
# <a href="/cms/ASSOCIATE_DEAN/1098" id="uc_header1_rpMenu_rpSub_0_lnkName_3">管理團隊</a>
# </li>
# <li>
# <a href="/cms/deeds" id="uc_header1_rpMenu_rpSub_0_lnkName_4">附醫大事紀</a>
# </li>
# <li>
# <a href="/cms/service" id="uc_header1_rpMenu_rpSub_0_lnkName_5">服務專區</a>
# </li>
# </ul>
# <div class="clearfix"></div>
# <input id="uc_header1_rpMenu_hidID_0" name="ctl00$uc_header1$rpMenu$ctl00$hidID" type="hidden" value="149"/>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" href="/team/team" id="uc_header1_rpMenu_lnkName_1" role="button">醫療專科</a>
# <div class="clearfix"></div>
# <input id="uc_header1_rpMenu_hidID_1" name="ctl00$uc_header1$rpMenu$ctl01$hidID" type="hidden" value="152"/>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" href="/feature/center" id="uc_header1_rpMenu_lnkName_2" role="button">醫療中心</a>
# <div class="clearfix"></div>
# <input id="uc_header1_rpMenu_hidID_2" name="ctl00$uc_header1$rpMenu$ctl02$hidID" type="hidden" value="153"/>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="../uc/#" id="uc_header1_rpMenu_lnkName_3" role="button">就醫指南 <span class="caret"></span></a>
# <ul class="dropdown-menu" id="uc_header1_rpMenu_subMenu_3" role="menu">
# <li>
# <a href="/service/regist" id="uc_header1_rpMenu_rpSub_3_lnkName_0">掛號服務</a>
# </li>
# <li>
# <a href="http://219.87.146.148/newreg/RegCncl.asp" id="uc_header1_rpMenu_rpSub_3_lnkName_1" target="_blank">醫師停代診查詢</a>
# </li>
# <li>
# <a href="/guide/outpatient" id="uc_header1_rpMenu_rpSub_3_lnkName_2">門診服務</a>
# </li>
# <li>
# <a href="/guide/turn" id="uc_header1_rpMenu_rpSub_3_lnkName_3">轉/檢診服務流程</a>
# </li>
# <li>
# <a href="/guide/expense" id="uc_header1_rpMenu_rpSub_3_lnkName_4">自費項目</a>
# </li>
# <li>
# <a href="/guide/receiveMedicine" id="uc_header1_rpMenu_rpSub_3_lnkName_5">領藥須知</a>
# </li>
# <li>
# <a href="http://219.87.146.148/HMSS/" id="uc_header1_rpMenu_rpSub_3_lnkName_6" target="_blank">個人用藥專區</a>
# </li>
# <li>
# <a href="/guide/emergency" id="uc_header1_rpMenu_rpSub_3_lnkName_7">急診服務</a>
# </li>
# <li>
# <a href="/guide/inpatient" id="uc_header1_rpMenu_rpSub_3_lnkName_8">住院服務</a>
# </li>
# <li>
# <a href="http://219.87.146.148/ipd_bed/" id="uc_header1_rpMenu_rpSub_3_lnkName_9" target="_blank">病床一覽表</a>
# </li>
# <li>
# <a href="/guide/apply" id="uc_header1_rpMenu_rpSub_3_lnkName_10">文件申請</a>
# </li>
# <li>
# <a href="/guide/right" id="uc_header1_rpMenu_rpSub_3_lnkName_11">病人權利與義務</a>
# </li>
# <li>
# <a href="/guide/traffic" id="uc_header1_rpMenu_rpSub_3_lnkName_12">交通資訊</a>
# </li>
# <li>
# <a href="/guide/FloorIntro" id="uc_header1_rpMenu_rpSub_3_lnkName_13">樓層介紹</a>
# </li>
# </ul>
# <div class="clearfix"></div>
# <input id="uc_header1_rpMenu_hidID_3" name="ctl00$uc_header1$rpMenu$ctl03$hidID" type="hidden" value="150"/>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="../uc/#" id="uc_header1_rpMenu_lnkName_4" role="button">訊息專區 <span class="caret"></span></a>
# <ul class="dropdown-menu" id="uc_header1_rpMenu_subMenu_4" role="menu">
# <li>
# <a href="/news/home" id="uc_header1_rpMenu_rpSub_4_lnkName_0">最新消息</a>
# </li>
# <li>
# <a href="/decree/healthcare" id="uc_header1_rpMenu_rpSub_4_lnkName_1">公開訊息</a>
# </li>
# <li>
# <a href="/epaper/epaper" id="uc_header1_rpMenu_rpSub_4_lnkName_2">健康報/門診時刻表</a>
# </li>
# <li>
# <a href="/thankful/internal" id="uc_header1_rpMenu_rpSub_4_lnkName_3">感恩園地</a>
# </li>
# <li>
# <a href="/media/2024" id="uc_header1_rpMenu_rpSub_4_lnkName_4">新聞發布</a>
# </li>
# <li>
# <a href="/recruit" id="uc_header1_rpMenu_rpSub_4_lnkName_5">招募新夥伴</a>
# </li>
# <li>
# <a href="/guide/covid19" id="uc_header1_rpMenu_rpSub_4_lnkName_6">新冠肺炎專區</a>
# </li>
# <li>
# <a href="/team/staff/47/848" id="uc_header1_rpMenu_rpSub_4_lnkName_7">病人就醫滿意度調查</a>
# </li>
# </ul>
# <div class="clearfix"></div>
# <input id="uc_header1_rpMenu_hidID_4" name="ctl00$uc_header1$rpMenu$ctl04$hidID" type="hidden" value="154"/>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="/guide/searchhealth" id="uc_header1_rpMenu_lnkName_5" role="button">衛教資訊 <span class="caret"></span></a>
# <ul class="dropdown-menu" id="uc_header1_rpMenu_subMenu_5" role="menu">
# <li>
# <a href="/guide/searchhealth" id="uc_header1_rpMenu_rpSub_5_lnkName_0">疾病衛教</a>
# </li>
# <li>
# <a href="/guide/searchhealth2?vm=3" id="uc_header1_rpMenu_rpSub_5_lnkName_1">檢查衛教</a>
# </li>
# <li>
# <a href="/team/medical/88/673" id="uc_header1_rpMenu_rpSub_5_lnkName_2">用藥衛教</a>
# </li>
# <li>
# <a href="/team/medical/87/667" id="uc_header1_rpMenu_rpSub_5_lnkName_3">營養衛教</a>
# </li>
# <li>
# <a href="/team/medical/86/794" id="uc_header1_rpMenu_rpSub_5_lnkName_4">預防跌倒</a>
# </li>
# <li>
# <a href="/news/film2" id="uc_header1_rpMenu_rpSub_5_lnkName_5">影音專區</a>
# </li>
# <li>
# <a href="/decree/SMD" id="uc_header1_rpMenu_rpSub_5_lnkName_6">醫病共享決策</a>
# </li>
# <li>
# <a href="/decree/ACP" id="uc_header1_rpMenu_rpSub_5_lnkName_7">預立醫療照護諮商</a>
# </li>
# </ul>
# <div class="clearfix"></div>
# <input id="uc_header1_rpMenu_hidID_5" name="ctl00$uc_header1$rpMenu$ctl05$hidID" type="hidden" value="420"/>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="../uc/#" id="uc_header1_rpMenu_lnkName_6" role="button">社會關懷 <span class="caret"></span></a>
# <ul class="dropdown-menu" id="uc_header1_rpMenu_subMenu_6" role="menu">
# <li>
# <a href="/pay/aims" id="uc_header1_rpMenu_rpSub_6_lnkName_0">社區關懷</a>
# </li>
# <li>
# <a href="/pay/truth" id="uc_header1_rpMenu_rpSub_6_lnkName_1">國際關懷</a>
# </li>
# <li>
# <a href="/pay/fundraising" id="uc_header1_rpMenu_rpSub_6_lnkName_2">募款專區</a>
# </li>
# <li>
# <a href="/pay/donation" id="uc_header1_rpMenu_rpSub_6_lnkName_3">志願服務</a>
# </li>
# </ul>
# <div class="clearfix"></div>
# <input id="uc_header1_rpMenu_hidID_6" name="ctl00$uc_header1$rpMenu$ctl06$hidID" type="hidden" value="272"/>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" href="/team/staff/107/864" id="uc_header1_rpMenu_lnkName_7" role="button">永續發展</a>
# <div class="clearfix"></div>
# <input id="uc_header1_rpMenu_hidID_7" name="ctl00$uc_header1$rpMenu$ctl07$hidID" type="hidden" value="1558"/>
# </li>
# <li class="dropdown mobile_show">
# <a class="dropdown-toggle direction" href="https://english.tmuh.org.tw/">
# <div class="menu_item">
#                             English
#                         </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="container" style="margin-top: 160px;">
# <ol class="breadcrumb">
# <li><a href="/"><i class="fa fa-home"></i> 首頁</a></li>
# </ol>
# </div>
# <div class="container page-body">
# <div class="row">
# <div class="col-sm-2 hidden-xs">
# <nav id="rightMenu">
# <h3>招募新夥伴</h3>
# <ul aria-multiselectable="true" class="nav nav-pills nav-stacked" id="accordion" role="tablist">
# <li id="job_619">
# <a href="/recruit/619" id="MainPlaceHolder_uc_recruit_menu1_rpMenu_lnkName_0">住院醫師</a>
# </li>
# <li id="job_620">
# <a href="/recruit/620" id="MainPlaceHolder_uc_recruit_menu1_rpMenu_lnkName_1">主治醫師</a>
# </li>
# <li id="job_621">
# <a href="/recruit/621" id="MainPlaceHolder_uc_recruit_menu1_rpMenu_lnkName_2">醫事人員</a>
# </li>
# <li id="job_622">
# <a href="/recruit/622" id="MainPlaceHolder_uc_recruit_menu1_rpMenu_lnkName_3">護理人員</a>
# </li>
# <li id="job_623">
# <a href="/recruit/623" id="MainPlaceHolder_uc_recruit_menu1_rpMenu_lnkName_4">行政人員</a>
# </li>
# <li id="dr">
# <a href="/recruit/special07">員工福利</a>
# </li>
# </ul>
# <input id="MainPlaceHolder_hidCode" name="ctl00$MainPlaceHolder$hidCode" type="hidden" value="619"/>
# </nav>
# </div>
# <div class="col-sm-10">
# <div class="page-header">
# <!-- ShareThis BEGIN --><div class="sharethis-inline-share-buttons" data-title="北醫附醫-招募新夥伴"></div><!-- ShareThis END -->
# <h3 class="title"><i class="glyphicon glyphicon-new-window"></i> 訊息專區 - 招募新夥伴</h3>
# </div>
# <div class="text-right">
# <a href="/F-E300-009-form-1010917.doc" target="_blank"><i class="glyphicon glyphicon-download-alt"></i> 附件下載-甄選資料表</a>
# </div>
# <!--內容-->
# <div class="row">
# <div class="col-sm-12">
# <table class="table table-bordered recruit">
# <div id="MainPlaceHolder_pljob">
# <!--20210511加入員工福利 /recruit/special07時消失 -->
# <tr>
# <th>單位</th>
# <th>職稱</th>
# </tr>
# </div>
# <tr>
# <td>PGY住院醫師</td>
# <td>
# <div>
# <a data-target="#REC_1460" data-toggle="modal" href="#">113學年度二年期西醫PGY住院醫師(實際招募容額依衛生福利部核定之113年度訓練容額公告為主)</a>
# <!-- Modal -->
# <div aria-labelledby="myModalLabel" class="modal fade" id="REC_1460" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h3 class="modal-title" id="myModalLabel">PGY住院醫師 - 113學年度二年期西醫PGY住院醫師(實際招募容額依衛生福利部核定之113年度訓練容額公告為主)</h3>
# </div>
# <div class="modal-body">
# <table class="table table-bordered table-striped recruit">
# <tr>
# <td class="name">學歷</td>
# <td>醫學系、學士後醫學系或中醫學系選醫學系雙主修畢業生</td>
# </tr>
# <tr>
# <td class="name">工作經歷</td>
# <td></td>
# </tr>
# <tr>
# <td class="name">工作內容</td>
# <td></td>
# </tr>
# <tr>
# <td class="name">具備文件</td>
# <td>一、應屆畢業生：<br/>1.本院網站甄選資料表<br/>2.自傳（不限定格式）<br/>3.歷年成績單影本（含全年及總人數及歷年成績總排名）<br/>4.通過第一階段國考成績證明<br/>5.如男性免役或延役者須檢附相關證明<br/><br/>二、非應屆畢業生：<br/>1.本院網站甄選資料表<br/>2.自傳（不限定格式）<br/>3.歷年成績單影本（含全年及總人數及歷年成績總排名）<br/>4.醫師證書正反面影本<br/>5.畢業證書正反面影本<br/>6.兵役相關證明文件，現役者請註明預定退伍日期</td>
# </tr>
# <tr>
# <td class="name">甄選方式</td>
# <td>資料繳交期限：113年01月26日（星期五）<br/>甄試日期：112年02月24日（星期六）<br/>(具備文件請依照一般醫學訓練選配系統載明為主)<br/><br/>甄選方式：<br/>請於「二年期一般醫學訓練選配系統」完成線上報名。<br/>並將甄試資料郵寄至<br/>11031臺北市信義區吳興街252號<br/>臺北醫學大學附設醫院第一醫療大樓七樓教學部 (註：113年度二年期PGY住院醫師 甄試 收)</td>
# </tr>
# <tr>
# <td class="name">聯絡方式</td>
# <td>（02）2737-2181轉3751 張小姐<br/>E-mail：225027@h.tmu.edu.tw</td>
# </tr>
# <tr>
# <td class="name">備註</td>
# <td></td>
# </tr>
# </table>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button"><i class="fa fa-close"></i> 關閉</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div>
# <a data-target="#REC_1463" data-toggle="modal" href="#">112學年度二年期西醫PGY住院醫師(實際招募容額依衛生福利部核定之112年度訓練容額公告為主)</a>
# <!-- Modal -->
# <div aria-labelledby="myModalLabel" class="modal fade" id="REC_1463" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h3 class="modal-title" id="myModalLabel">PGY住院醫師 - 112學年度二年期西醫PGY住院醫師(實際招募容額依衛生福利部核定之112年度訓練容額公告為主)</h3>
# </div>
# <div class="modal-body">
# <table class="table table-bordered table-striped recruit">
# <tr>
# <td class="name">學歷</td>
# <td>醫學系、學士後醫學系或中醫學系選醫學系雙主修畢業生</td>
# </tr>
# <tr>
# <td class="name">工作經歷</td>
# <td></td>
# </tr>
# <tr>
# <td class="name">工作內容</td>
# <td></td>
# </tr>
# <tr>
# <td class="name">具備文件</td>
# <td>一、應屆畢業生：<br/>1.本院網站甄選資料表<br/>2.自傳（不限定格式）<br/>3.歷年成績單影本（含全年及總人數及歷年成績總排名）<br/>4.通過第一階段國考成績證明<br/>5.如男性免役或延役者須檢附相關證明<br/><br/><br/>二、非應屆畢業生：<br/>1.本院網站甄選資料表<br/>2.自傳（不限定格式）<br/>3.歷年成績單影本（含全年及總人數及歷年成績總排名）<br/>4.醫師證書正反面影本<br/>5.畢業證書正反面影本<br/>6.兵役相關證明文件，現役者請註明預定退伍日期</td>
# </tr>
# <tr>
# <td class="name">甄選方式</td>
# <td>資料繳交期限：113年05月10日(星期五)<br/>請將甄試資料郵寄至<br/>11031臺北市信義區吳興街252號<br/>臺北醫學大學附設醫院第一醫療大樓七樓教學部 (註：112年度二年期PGY住院醫師 甄試 收)<br/>※甄試日期另行通知</td>
# </tr>
# <tr>
# <td class="name">聯絡方式</td>
# <td>（02）2737-2181轉3750 張小姐<br/>E-mail：225027@h.tmu.edu.tw</td>
# </tr>
# <tr>
# <td class="name">備註</td>
# <td></td>
# </tr>
# </table>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button"><i class="fa fa-close"></i> 關閉</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <input id="MainPlaceHolder_rpData_hidCate_0" name="ctl00$MainPlaceHolder$rpData$ctl00$hidCate" type="hidden" value="住院醫師"/>
# <input id="MainPlaceHolder_rpData_hidDept_0" name="ctl00$MainPlaceHolder$rpData$ctl00$hidDept" type="hidden" value="PGY住院醫師"/>
# </td>
# </tr>
# <tr>
# <td>小兒科</td>
# <td>
# <div>
# <a data-target="#REC_1396" data-toggle="modal" href="#">111年度兒科第一年住院醫師(R1) 1名</a>
# <!-- Modal -->
# <div aria-labelledby="myModalLabel" class="modal fade" id="REC_1396" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h3 class="modal-title" id="myModalLabel">小兒科 - 111年度兒科第一年住院醫師(R1) 1名</h3>
# </div>
# <div class="modal-body">
# <table class="table table-bordered table-striped recruit">
# <tr>
# <td class="name">學歷</td>
# <td>1.醫學院醫學系、學士後醫學系，已具本國醫師證書，且已完成畢業後一般醫學訓練。
# 2.國外醫學院畢業者，須取得中華民國醫師證書始具報考資格。
# 3.外國籍醫師報考應檢附外僑長期居留證明及勞委會核發之工作許可函。</td>
# </tr>
# <tr>
# <td class="name">工作經歷</td>
# <td></td>
# </tr>
# <tr>
# <td class="name">工作內容</td>
# <td>住院醫師</td>
# </tr>
# <tr>
# <td class="name">具備文件</td>
# <td>1.本院網站甄選資料表 (請至本院網站下載https://www.tmuh.org.tw/recruit)<br/>2.醫師證書影本<br/>3.PGY訓練證明<br/>4.畢業證書影本<br/>5.在校成績單並附名次<br/>6.兵役相關證明<br/>7.履歷自傳一份<br/>8.面試當天準備10分鐘自我介紹簡報(含PGY實習心得)<br/>9.若有其他特殊學經歷請一併檢附相關證明文件</td>
# </tr>
# <tr>
# <td class="name">甄選方式</td>
# <td>請將履歷寄至信箱：ped@h.tmu.edu.tw，收到履歷後將安排面試時間</td>
# </tr>
# <tr>
# <td class="name">聯絡方式</td>
# <td>（02）2737-2181轉3715 宋小姐<br/>E-mail：ped@h.tmu.edu.tw</td>
# </tr>
# <tr>
# <td class="name">備註</td>
# <td></td>
# </tr>
# </table>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button"><i class="fa fa-close"></i> 關閉</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <input id="MainPlaceHolder_rpData_hidCate_1" name="ctl00$MainPlaceHolder$rpData$ctl01$hidCate" type="hidden" value="住院醫師"/>
# <input id="MainPlaceHolder_rpData_hidDept_1" name="ctl00$MainPlaceHolder$rpData$ctl01$hidDept" type="hidden" value="小兒科"/>
# </td>
# </tr>
# <tr>
# <td>內科部</td>
# <td>
# <div>
# <a data-target="#REC_1446" data-toggle="modal" href="#">113學年內科部住院醫師(實際招募容額依衛生福利部核定之113年度訓練容額公告為主)</a>
# <!-- Modal -->
# <div aria-labelledby="myModalLabel" class="modal fade" id="REC_1446" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h3 class="modal-title" id="myModalLabel">內科部 - 113學年內科部住院醫師(實際招募容額依衛生福利部核定之113年度訓練容額公告為主)</h3>
# </div>
# <div class="modal-body">
# <table class="table table-bordered table-striped recruit">
# <tr>
# <td class="name">學歷</td>
# <td>1.醫學院醫學系、學士後醫學系，已具本國醫師證書，且已完成畢業後一般醫學訓練。
# 2.國外醫學院畢業者，須取得中華民國醫師證書始具報考資格。
# 3.外國籍醫師報考應檢附外僑長期居留證明及勞委會核發之工作許可函。</td>
# </tr>
# <tr>
# <td class="name">工作經歷</td>
# <td>具PGY2完訓。</td>
# </tr>
# <tr>
# <td class="name">工作內容</td>
# <td>住院醫師。</td>
# </tr>
# <tr>
# <td class="name">具備文件</td>
# <td>1.本院網站甄選資料表 (請至本院網站下載https://www.tmuh.org.tw/recruit)<br/>2.醫師證書影本<br/>3.PGY訓練證明<br/>4.畢業證書影本<br/>5.在校成績單並附名次<br/>6.兵役相關證明<br/>7.履歷自傳一份<br/>8.若有其他特殊學經歷請一併檢附相關證明文件</td>
# </tr>
# <tr>
# <td class="name">甄選方式</td>
# <td>請將履歷於112/11/15(三)前寄至信箱：samuellin@tmu.edu.tw，收到履歷後將安排面試，面試時間：112/11/23(四) 16:00</td>
# </tr>
# <tr>
# <td class="name">聯絡方式</td>
# <td>（02）2737-2181轉3577 林先生<br/>E-mail：samuellin@.tmu.edu.tw</td>
# </tr>
# <tr>
# <td class="name">備註</td>
# <td></td>
# </tr>
# </table>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button"><i class="fa fa-close"></i> 關閉</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <input id="MainPlaceHolder_rpData_hidCate_2" name="ctl00$MainPlaceHolder$rpData$ctl02$hidCate" type="hidden" value="住院醫師"/>
# <input id="MainPlaceHolder_rpData_hidDept_2" name="ctl00$MainPlaceHolder$rpData$ctl02$hidDept" type="hidden" value="內科部"/>
# </td>
# </tr>
# <tr>
# <td>牙周病科</td>
# <td>
# <div>
# <a data-target="#REC_1244" data-toggle="modal" href="#">牙科部牙周病科專科門診中心-專任專科訓練住院醫師1名</a>
# <!-- Modal -->
# <div aria-labelledby="myModalLabel" class="modal fade" id="REC_1244" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h3 class="modal-title" id="myModalLabel">牙周病科 - 牙科部牙周病科專科門診中心-專任專科訓練住院醫師1名</h3>
# </div>
# <div class="modal-body">
# <table class="table table-bordered table-striped recruit">
# <tr>
# <td class="name">學歷</td>
# <td>國內外牙醫學系畢業</td>
# </tr>
# <tr>
# <td class="name">工作經歷</td>
# <td
td>
# </tr>
# <tr>
# <td class="name">備註</td>
# <td></td>
# </tr>
# </table>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button"><i class="fa fa-close"></i> 關閉</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <input id="MainPlaceHolder_rpData_hidCate_11" name="ctl00$MainPlaceHolder$rpData$ctl11$hidCate" type="hidden" value="住院醫師"/>
# <input id="MainPlaceHolder_rpData_hidDept_11" name="ctl00$MainPlaceHolder$rpData$ctl11$hidDept" type="hidden" value="病理科"/>
# </td>
# </tr>
# <tr>
# <td>神經內科</td>
# <td>
# <div>
# <a data-target="#REC_1418" data-toggle="modal" href="#">神經科113年第1年住院醫師1名</a>
# <!-- Modal -->
# <div aria-labelledby="myModalLabel" class="modal fade" id="REC_1418" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h3 class="modal-title" id="myModalLabel">神經內科 - 神經科113年第1年住院醫師1名</h3>
# </div>
# <div class="modal-body">
# <table class="table table-bordered table-striped recruit">
# <tr>
# <td class="name">學歷</td>
# <td>國內公(私)立大學醫學系畢業或中醫系畢業</td>
# </tr>
# <tr>
# <td class="name">工作經歷</td>
# <td>具PGY2完訓</td>
# </tr>
# <tr>
# <td class="name">工作內容</td>
# <td>住院醫師</td>
# </tr>
# <tr>
# <td class="name">具備文件</td>
# <td>1.本院網站甄選資料表(https://www.tmuh.org.tw/recruit)<br/>2.醫師證書影本<br/>3.PGY訓練證明(未完訓者請提供服務證明)<br/>4.畢業證書影本<br/>5.成績單並附名次<br/>6.履歷自傳一份<br/>7.若為內/外/婦/兒科分組者，請於履歷中註明<br/>8.退伍令或相關免服役證明<br/>9.若有其他特殊學經歷(請一併檢附相關證明文件)</td>
# </tr>
# <tr>
# <td class="name">甄選方式</td>
# <td>郵寄或e-mail所需具備文件，由本科篩選適合人選後通知面試。<br/>■郵寄：臺北市信義區吳興街252號 神經內科 羅秘書收(註明應甄<br/>職務)<br/>■E-mail：neurol@h.tmu.edu.tw</td>
# </tr>
# <tr>
# <td class="name">聯絡方式</td>
# <td>電話：(02)27372181轉8257</td>
# </tr>
# <tr>
# <td class="name">備註</td>
# <td></td>
# </tr>
# </table>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button"><i class="fa fa-close"></i> 關閉</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <input id="MainPlaceHolder_rpData_hidCate_12" name="ctl00$MainPlaceHolder$rpData$ctl12$hidCate" type="hidden" value="住院醫師"/>
# <input id="MainPlaceHolder_rpData_hidDept_12" name="ctl00$MainPlaceHolder$rpData$ctl12$hidDept" type="hidden" value="神經內科"/>
# </td>
# </tr>
# <tr>
# <td>神經外科</td>
# <td>
# <div>
# <a data-target="#REC_1443" data-toggle="modal" href="#">113年度神經外科住院醫師</a>
# <!-- Modal -->
# <div aria-labelledby="myModalLabel" class="modal fade" id="REC_1443" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h3 class="modal-title" id="myModalLabel">神經外科 - 113年度神經外科住院醫師</h3>
# </div>
# <div class="modal-body">
# <table class="table table-bordered table-striped recruit">
# <tr>
# <td class="name">學歷</td>
# <td>大學以上醫學系相關</td>
# </tr>
# <tr>
# <td class="name">工作經歷</td>
# <td></td>
# </tr>
# <tr>
# <td class="name">工作內容</td>
# <td>住院醫師</td>
# </tr>
# <tr>
# <td class="name">具備文件</td>
# <td>．具備文件：<br/>1.本院網站甄選資料表<br/>2.醫師證書影本<br/>3.PGY訓練證明(未完訓者請提供服務證明)<br/>4.畢業證書影本<br/>5.成績單並附名次<br/>6.履歷自傳一份<br/>7.退伍令或相關免服役證明<br/>8.若有其他特殊學經歷(請一併檢附相關證明文件)</td>
# </tr>
# <tr>
# <td class="name">甄選方式</td>
# <td>1.請寄電子履歷neurosurgery@h.tmu.edu.tw或紙本履歷至台北市信義區吳興街252號 神經外科 高秘書 收，經初審合格者，將由面試單位通知時間與地點。<br/>2.如有特殊狀況或相關問題詢問，敬請聯繫教學部。</td>
# </tr>
# <tr>
# <td class="name">聯絡方式</td>
# <td>■郵寄：11031台北市信義區吳興街252號B1 神經外科辦公室<br/>■E-mail：neurosurgery@h.tmu.edu.tw<br/>■電話：（02）2737-2181轉3031神經外科 高秘書</td>
# </tr>
# <tr>
# <td class="name">備註</td>
# <td></td>
# </tr>
# </table>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button"><i class="fa fa-close"></i> 關閉</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <input id="MainPlaceHolder_rpData_hidCate_13" name="ctl00$MainPlaceHolder$rpData$ctl13$hidCate" type="hidden" value="住院醫師"/>
# <input id="MainPlaceHolder_rpData_hidDept_13" name="ctl00$MainPlaceHolder$rpData$ctl13$hidDept" type="hidden" value="神經外科"/>
# </td>
# </tr>
# <tr>
# <td>婦產科</td>
# <td>
# <div>
# <a data-target="#REC_1414" data-toggle="modal" href="#">113學年度PGY2(婦產組)</a>
# <!-- Modal -->
# <div aria-labelledby="myModalLabel" class="modal fade" id="REC_1414" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h3 class="modal-title" id="myModalLabel">婦產科 - 113學年度PGY2(婦產組)</h3>
# </div>
# <div class="modal-body">
# <table class="table table-bordered table-striped recruit">
# <tr>
# <td class="name">學歷</td>
# <td>大學以上醫學系相關</td>
# </tr>
# <tr>
# <td class="name">工作經歷</td>
# <td></td>
# </tr>
# <tr>
# <td class="name">工作內容</td>
# <td></td>
# </tr>
# <tr>
# <td class="name">具備文件</td>
# <td>1.本院制式甄選資料表（表格網路下載） <br/>2.成績單並附名次<br/>3.履歷自傳一份<br/>4.醫學系畢業證書影本 <br/>5.醫師證書影本或國考成績單 <br/>6.PGY完訓證明、PGY受訓醫院識別證影本或在職證明<br/>7.若為二年制內外婦兒科組者，請特別於履歷中註明<br/>8.退伍令或相關免服役證明<br/>9. 其他相關資料(其他考試證書、證照、特殊事蹟、特殊經歷證明等)</td>
# </tr>
# <tr>
# <td class="name">甄選方式</td>
# <td>1.歡迎有興趣者，將上述資料以電子檔方式寄至215173@h.tmu.edu.tw 或郵寄方式至台北市信義區吳興街252號 (三大樓B1婦產部辦公室)婦產部秘書收<br/>2.收件截止至113年4月30日，經初審合格者將由面試單位通知時間與地點 <br/>3.如有特殊狀況或相關問題詢問，敬請聯繫。</td>
# </tr>
# <tr>
# <td class="name">聯絡方式</td>
# <td>郵寄：台北市信義區吳興街252號 (三大樓B1婦產部辦公室)<br/>E-mail：215173@h.tmu.edu.tw<br/>電話：(02)2737-21815轉3519婦產科秘書</td>
# </tr>
# <tr>
# <td class="name">備註</td>
# <td></td>
# </tr>
# </table>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button"><i class="fa fa-close"></i> 關閉</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <input id="MainPlaceHolder_rpData_hidCate_14" name="ctl00$MainPlaceHolder$rpData$ctl14$hidCate" type="hidden" value="住院醫師"/>
# <input id="MainPlaceHolder_rpData_hidDept_14" name="ctl00$MainPlaceHolder$rpData$ctl14$hidDept" type="hidden" value="婦產科"/>
# </td>
# </tr>
# <tr>
# <td>齒顎矯正科</td>
# <td>
# <div>
# <a data-target="#REC_1401" data-toggle="modal" href="#">113年度臺北醫學大學附設醫院牙科部齒顎矯正科-專科代訓住院醫師</a>
# <!-- Modal -->
# <div aria-labelledby="myModalLabel" class="modal fade" id="REC_1401" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h3 class="modal-title" id="myModalLabel">齒顎矯正科 - 113年度臺北醫學大學附設醫院牙科部齒顎矯正科-專科代訓住院醫師</h3>
# </div>
# <div class="modal-body">
# <table class="table table-bordered table-striped recruit">
# <tr>
# <td class="name">學歷</td>
# <td>國內外牙醫學系畢業且到職前PGY完訓者</td>
# </tr>
# <tr>
# <td class="name">工作經歷</td>
# <td></td>
# </tr>
# <tr>
# <td class="name">工作內容</td>
# <td>齒顎矯正專科醫師訓練<br/>執行相關臨床、研究及教學業務<br/>於113年08月01日到職者為佳</td>
# </tr>
# <tr>
# <td class="name">具備文件</td>
# <td>1. 畢業證書影本<br/>2. 牙醫師證書影本<br/>3. PGY完訓證明或在職證明<br/>4. 本院網站甄選資料表(請務必註明聯絡電話及e-mail)<br/>5. 退伍令或相關免服役證明<br/>6. 自選：履歷自傳等其他有利甄選資料(若含其他特殊學經歷請一併檢附相關文件)<br/>以上資料請郵寄至本科(詳見聯絡方式)，收到後會依資料所附e-mail回覆確認報名</td>
# </tr>
# <tr>
# <td class="name">甄選方式</td>
# <td>報名收件至113年03月09日(郵戳為憑)<br/>筆試及口試日期：暫定113年03月16日<br/>(詳細資訊報名後將個別通知)</td>
# </tr>
# <tr>
# <td class="name">聯絡方式</td>
# <td>相關文件請郵寄至臺北市信義區吳興街252號 牙科部齒顎矯正科 黃冠中醫師收<br/>若有其他問題請電洽(02)27372181轉3211再轉6 黃冠中醫師</td>
# </tr>
# <tr>
# <td class="name">備註</td>
# <td>本單位保留隨時修改、變更、暫停或終止本招募內容之權利，若有更動以最新公告為準</td>
# </tr>
# </table>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button"><i class="fa fa-close"></i> 關閉</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <input id="MainPlaceHolder_rpData_hidCate_15" name="ctl00$MainPlaceHolder$rpData$ctl15$hidCate" type="hidden" value="住院醫師"/>
# <input id="MainPlaceHolder_rpData_hidDept_15" name="ctl00$MainPlaceHolder$rpData$ctl15$hidDept" type="hidden" value="齒顎矯正科"/>
# </td>
# </tr>
# <tr>
# <td>膺復牙科</td>
# <td>
# <div>
# <a data-target="#REC_1461" data-toggle="modal" href="#">牙科部贋復牙科 專任專科訓練住院醫師</a>
# <!-- Modal -->
# <div aria-labelledby="myModalLabel" class="modal fade" id="REC_1461" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h3 class="modal-title" id="myModalLabel">膺復牙科 - 牙科部贋復牙科 專任專科訓練住院醫師</h3>
# </div>
# <div class="modal-body">
# <table class="table table-bordered table-striped recruit">
# <tr>
# <td class="name">學歷</td>
# <td>國內外牙醫學系畢業到職前PGY完訓</td>
# </tr>
# <tr>
# <td class="name">工作經歷</td>
# <td></td>
# </tr>
# <tr>
# <td class="name">工作內容</td>
# <td>專科醫師訓練<br/>執行臨床業務<br/>負擔部分行政與教學工作</td>
# </tr>
# <tr>
# <td class="name">具備文件</td>
# <td>1.畢業證書影本　<br/>2.自傳　<br/>3.牙醫師證書影印本<br/>4.PGY完訓證明(最遲須於到職前取得並繳交完訓證明)<br/>5.男性請檢附退伍令影本、補充兵役或免役證明影本<br/>6.本院網站甄選資料表(請務必註明聯絡電話及e-mail)</td>
# </tr>
# <tr>
# <td class="name">甄選方式</td>
# <td>請將報名資料寄至 dentintako@gmail.com<br/>五日內會回覆報名成功之訊息	<br/>報名後由本科通知安排面談，報名期限至113/04/20</td>
# </tr>
# <tr>
# <td class="name">聯絡方式</td>
# <td>E-mail：dentintako@gmail.com<br/>電話：(02)27372181-3211-5</td>
# </tr>
# <tr>
# <td class="name">備註</td>
# <td></td>
# </tr>
# </table>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button"><i class="fa fa-close"></i> 關閉</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <input id="MainPlaceHolder_rpData_hidCate_16" name="ctl00$MainPlaceHolder$rpData$ctl16$hidCate" type="hidden" value="住院醫師"/>
# <input id="MainPlaceHolder_rpData_hidDept_16" name="ctl00$MainPlaceHolder$rpData$ctl16$hidDept" type="hidden" value="膺復牙科"/>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="dots" style="margin-top: 30px;"></div>
# <div class="container" style="margin-top: 30px;">
# <div class="row">
# <div class="col-xs-12 col-sm-5 col-md-5 col-lg-5 text-center hidden-xs"><img src="/images/logo.jpg" style="width: 100%;"/></div>
# <div class="col-xs-12 col-sm-7 col-md-5 col-lg-7 text-center"><img src="/images/badge.jpg" style="width: 100%;"/></div>
# </div>
# </div>
# <div class="footer">
# <ul>
# <li>總　機 ：(02) 2737-2181</li><li>|</li>
# <li>語音預約 ：(02) 2377-1323 ;(02) 2377-1866</li><li>|</li>
# <li><a href="/service/regist">網路掛號</a></li> | <li>
# <li><a href="https://consent.tmuh.org.tw/tocc_ipd" target="_blank">陪/探病申請</a></li><li>
# </li></li></ul>
# </div>
# <div class="text-center fmenu hidden-xs">
# <ul>
# <li><a href="/">首頁</a></li><li>|</li>
# <li><a href="http://www.tmu.edu.tw" rel="noopener noreferrer" target="_blank">臺北醫學大學</a></li><li>|</li>
# <li><a href="http://www.wanfang.gov.tw" rel="noopener noreferrer" target="_blank">萬芳醫院</a></li><li>|</li>
# <li><a href="https://shh.tmu.edu.tw" rel="noopener noreferrer" target="_blank">雙和醫院</a></li><li>|</li>
# <li><a href="http://www.skmh.com.tw/" rel="noopener noreferrer" target="_blank">新國民醫院</a></li><li>|</li>
# <li><a href="https://www.cancertaipei.tw/" rel="noopener noreferrer" target="_blank">臺北癌症中心</a></li><li>|</li>
# <li><a href="https://www.taipeineuro.org.tw/" rel="noopener noreferrer" target="_blank">臺北神經醫學中心</a></li><li>|</li>
# <li><a href="/decree/healthcare">政令宣導</a></li><li>|</li>
# <li><a href="/guide/traffic">交通資訊</a></li>
# </ul>
# </div>
# <div class="container text-center copyright">
# <div class="row">
# <div class="col-lg-2 col-sm-6">地址：110301臺北市信義區吳興街252號</div>
# <div class="col-lg-2 col-sm-6">代表號：02-27372181</div>
# <div class="col-lg-4 col-sm-6">Copyright © 2024 臺北醫學大學附設醫院 版權所有</div>
# <div class="col-lg-4 col-sm-6">最佳瀏覽環境：IE8以上版本    <a href="https://www.tmuh.org.tw/cms/PRIVACY" rel="noopener noreferrer" target="_blank">資訊安全與隱私權政策</a></div>
# </div>
# </div>
# </form>
# </body>
# </html>
